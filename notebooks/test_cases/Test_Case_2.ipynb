# %%
import pandas as pd

# Load AIS data
ais_data = pd.read_csv('AIS_2024_01_01.csv')

# Convert BaseDateTime and COG to appropriate formats
ais_data['BaseDateTime'] = pd.to_datetime(ais_data['BaseDateTime'])
ais_data['COG'] = pd.to_numeric(ais_data['COG'], errors='coerce')  # Convert to float
ais_data = ais_data.dropna(subset=['COG'])  # Remove NaN values

# Sort by MMSI and BaseDateTime
ais_data = ais_data.sort_values(['MMSI', 'BaseDateTime'])

def detect_anomalies(df):
    anomalies = []
    unique_vessels = df['MMSI'].unique()
    flagged_vessels = set()

    for vessel in unique_vessels:
        if vessel in flagged_vessels:
            continue

        vessel_data = df[df['MMSI'] == vessel].reset_index(drop=True)

        for i in range(1, len(vessel_data)):
            previous_speed = vessel_data['SOG'].iloc[i - 1]
            current_speed = vessel_data['SOG'].iloc[i]
            speed_change = abs(current_speed - previous_speed)

            # Handle circular COG changes correctly
            cog_diff = abs(vessel_data['COG'].iloc[i] - vessel_data['COG'].iloc[i - 1])
            course_change = min(cog_diff, 360 - cog_diff)  # Handle wrap-around at 360°

            # Detect speed anomalies (>50% change relative to previous speed)
            if previous_speed > 2 and speed_change > 0.5 * previous_speed:
                anomalies.append(vessel_data.iloc[i])
                flagged_vessels.add(vessel)
                #break  # Stop checking further for this vessel

            # Detect course anomalies (>45° change at any speed)
            elif course_change > 45:
                anomalies.append(vessel_data.iloc[i])
                flagged_vessels.add(vessel)
                #break  # Stop checking further for this vessel

    return pd.DataFrame(anomalies)

# Run anomaly detection
anomalies_df = detect_anomalies(ais_data)
print("Anomalies detected:")
print(anomalies_df)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Anomalies detected:
#           MMSI        BaseDateTime       LAT        LON  SOG    COG  Heading  \
# 131          0 2024-01-01 07:52:59  36.91337  -76.18496  0.0  125.9    125.0
# 153          0 2024-01-01 09:34:59  36.91336  -76.18495  0.0  125.5    125.0
# 1         4061 2024-01-01 00:31:47  27.81622  -97.41844  0.0  254.9    511.0
# 2         4061 2024-01-01 01:49:47  27.81629  -97.41849  0.0    0.0    511.0
# 6         4061 2024-01-01 20:04:47  27.81629  -97.41839  0.0  257.8    511.0
# ..         ...                 ...       ...        ...  ...    ...      ...
# 235  987654321 2024-01-01 23:46:30  48.42098 -123.38656  0.0  241.0    322.0
# 236  987654321 2024-01-01 23:52:30  48.42098 -123.38656  0.0  191.5    322.0
# 237  987654321 2024-01-01 23:58:30  48.42099 -123.38655  0.0  250.6    322.0
# 2    993086011 2024-01-01 11:22:07  18.43478  -64.74649  1.0  120.3    511.0
# 3    993086011 2024-01-01 11:28:36  18.43459  -64.74571  1.4  166.3    511.0
#
#        VesselName         IMO CallSign  VesselType  Status  Length  Width  \
# 131       CG49420         NaN     NWHE        51.0     NaN    82.0   12.0
# 153       CG49420         NaN     NWHE        51.0     NaN    82.0   12.0
# 1    BOOSTER 9000  IMO0000000  0000000        33.0     NaN     0.0    0.0
# 2    BOOSTER 9000  IMO0000000  0000000        33.0     NaN     0.0    0.0
# 6    BOOSTER 9000  IMO0000000  0000000        33.0     NaN     0.0    0.0
# ..            ...         ...      ...         ...     ...     ...    ...
# 235          VIEW         NaN      NaN        37.0     5.0     0.0    0.0
# 236          VIEW         NaN      NaN        37.0     5.0     0.0    0.0
# 237          VIEW         NaN      NaN        37.0     5.0     0.0    0.0
# 2         SCREECH  IMO0000000  SCREECH        37.0     NaN    11.0    7.0
# 3         SCREECH  IMO0000000  SCREECH        37.0     NaN    11.0    7.0
#
#      Draft  Cargo TransceiverClass
# 131    1.6   51.0                B
# 153    1.6   51.0                B
# 1      NaN    NaN                B
# 2      NaN    NaN                B
# 6      NaN    NaN                B
# ..     ...    ...              ...
# 235    0.0   99.0                A
# 236    0.0   99.0                A
# 237    0.0   99.0                A
# 2      NaN    NaN                B
# 3      NaN    NaN                B
#
# [824375 rows x 17 columns]

# %%
# Install necessary packages
# !pip install geemap
# !pip install earthengine-api
# Install Earth Engine and Geemap
# !pip install earthengine-api geemap


# Authenticate and initialize Earth Engine
import ee
import geemap

# Trigger the authentication
ee.Authenticate()

# Initialize the Earth Engine API
ee.Initialize(project='ee-oilspilldetection-by-uday')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: geemap in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (0.35.3)
# Requirement already satisfied: bqplot in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.5.6)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.1.1)
# Requirement already satisfied: folium>=0.17.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.19.5)
# Requirement already satisfied: geocoder in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (3.8.2)
# Requirement already satisfied: numpy in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (2.1.4)
# Requirement already satisfied: plotly in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (6.0.0)
# Requirement already satisfied: pyperclip in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: google-cloud-storage in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api>=1.0.0->geemap) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.163.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.17.0->geemap) (2025.1.0)
# Requirement already satisfied: ipywidgets in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (3.2.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from plotly->geemap) (1.30.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: colorama in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2025.1.31)
# Requirement already satisfied: decorator in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ratelim->geocoder->geemap) (5.2.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.26.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: earthengine-api in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (1.5.6)
# Requirement already satisfied: google-cloud-storage in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (2.163.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: earthengine-api in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (1.5.6)
# Requirement already satisfied: geemap in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (0.35.3)
# Requirement already satisfied: google-cloud-storage in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (2.163.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: bqplot in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.1.1)
# Requirement already satisfied: folium>=0.17.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.19.5)
# Requirement already satisfied: geocoder in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (3.8.2)
# Requirement already satisfied: numpy in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (2.1.4)
# Requirement already satisfied: plotly in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (6.0.0)
# Requirement already satisfied: pyperclip in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.17.0->geemap) (2025.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.1)
# Requirement already satisfied: ipywidgets in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from geocoder->geemap) (1.17.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from requests->earthengine-api) (2025.1.31)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->geemap) (11.1.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from plotly->geemap) (1.30.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday kiran ambati\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: colorama in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: decorator in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ratelim->geocoder->geemap) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\uday kiran ambati\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)

# %%
def plot_histogram(image, region, title):
    try:
        array = image.reduceRegion(
            reducer=ee.Reducer.toList(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).get('VV')

        # Check if array is empty
        if array is None:
            print("No VV data available for histogram plot.")
            return

        array = np.array(array.getInfo())
        plt.hist(array, bins=50, color='blue', alpha=0.7)
        plt.title(title)
        plt.xlabel('VV (dB)')
        plt.ylabel('Frequency')
        plt.grid()
        plt.show()
    except Exception as e:
        print(f"Error plotting histogram: {e}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from datetime import datetime

# Function to parse date from BaseDateTime
def extract_date(base_date_time):
    # Convert to string if it’s a Timestamp
    if isinstance(base_date_time, pd.Timestamp):
        base_date_time = base_date_time.strftime('%Y-%m-%dT%H:%M:%S')
    else:
        base_date_time = str(base_date_time)

    # Parse the date
    date_time_obj = datetime.strptime(base_date_time, '%Y-%m-%dT%H:%M:%S')
    return date_time_obj.strftime('%Y-%m-%d')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def preprocess_image_for_model(image_np):
    """ Preprocess the NumPy array image to match model input requirements """
    # Resize the image to (256, 256)
    resized_image = cv2.resize(image_np, (256, 256))
    
    # Check the number of channels
    if resized_image.shape[-1] == 2:
        # Convert 2-channel input to 3-channel by duplicating one of the channels
        resized_image = np.repeat(resized_image[:, :, :1], 3, axis=-1)
    elif resized_image.shape[-1] == 1:
        # Convert 1-channel input to 3-channel
        resized_image = np.repeat(resized_image, 3, axis=-1)
    elif resized_image.shape[-1] != 3:
        raise ValueError(f"Unexpected number of channels: {resized_image.shape[-1]}")
    
    # Add a batch dimension
    return np.expand_dims(resized_image, axis=0)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import tensorflow as tf

# Define jaccard_coef if not already defined
def jaccard_coef(y_true, y_pred):
    y_true_flatten = tf.reshape(y_true, [-1])
    y_pred_flatten = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_flatten * y_pred_flatten)
    sum_ = tf.reduce_sum(y_true_flatten) + tf.reduce_sum(y_pred_flatten)
    smooth = 1e-6  # To avoid division by zero
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from tensorflow.keras.models import load_model
import os

# Ensure segmentation_models uses TensorFlow backend
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

# Load the models
hybrid_model = load_model(r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\hybrid_model.h5")
unet_model = load_model(r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\U_net.h5")
deeplab_model = load_model(
    r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\deeplab_model.h5",
    custom_objects={
        "jaccard_coef": jaccard_coef,  # Ensure this function is defined in your script
        "DiceLoss": sm.losses.DiceLoss(),  # Initialize the DiceLoss object
        "CategoricalFocalLoss": sm.losses.CategoricalFocalLoss()  # Initialize the CategoricalFocalLoss object
    }
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def preprocess_image_for_model(image_np):
    """ Preprocess the NumPy array image to match model input requirements """
    # Remove any extra dimensions if present (e.g., shape (256, 256, 1, 6) -> (256, 256, 2))
    if image_np.ndim == 4:
        image_np = image_np[:, :, :, 0]

    # Resize to 256x256
    resized_image = cv2.resize(image_np, (256, 256))

    # Ensure the image has three channels (duplicate one if necessary)
    if resized_image.shape[-1] == 2:
        resized_image = np.repeat(resized_image[:, :, :1], 3, axis=-1)
    elif resized_image.shape[-1] == 1:
        resized_image = np.repeat(resized_image, 3, axis=-1)

    # Add batch dimension
    return np.expand_dims(resized_image, axis=0)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def confirm_oil_spill(hybrid_model, unet_model, deeplab_model, image):
    """ 
    Confirm oil spill detection using Hybrid, UNet, and DeepLabV3+ models. 
    Requires agreement among all models.
    """
    processed_image = preprocess_image_for_model(image)

    processed_image = preprocess_image_for_model(image)
        
        # Get predictions from both models
    unet_prediction = unet_model.predict(processed_image)
    deeplab_prediction = deeplab_model.predict(processed_image)
    hybrid_prediction = hybrid_model.predict(processed_image)

    # Assuming '1' corresponds to oil spill for both models
    unet_result = np.argmax(unet_prediction) == 1
    deeplab_result = np.argmax(deeplab_prediction) == 1
    hybrid_result = np.argmax(hybrid_prediction) == 1

    # Confirm only if both models agree
    #return unet_result 

    # Confirm only if all models agree
    return hybrid_result and unet_result and deeplab_result
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from tensorflow.keras.models import load_model
import geemap
import ee
import numpy as np
import cv2
from IPython.display import display

def process_anomaly(row):
    lat = row['LAT']
    lon = row['LON']
    base_date_time = row['BaseDateTime']
    date = extract_date(base_date_time)
    anomaly_date = ee.Date(date)
    print(f"Processing anomaly at {lat}, {lon} on {date}")

    roi = ee.Geometry.Point(lon, lat).buffer(10000).bounds()
    detected_spills = []

    # Sentinel-1 collection
    sen1 = ee.ImageCollection("COPERNICUS/S1_GRD") \
        .filterDate(anomaly_date, anomaly_date.advance(1, 'day')) \
        .filterBounds(roi) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
        .filter(ee.Filter.eq('instrumentMode', 'IW'))

    if sen1.size().getInfo() == 0:
        print("No Sentinel-1 VV or VH images available. Trying Sentinel-2.")
        sen1 = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") \
            .filterDate(anomaly_date, anomaly_date.advance(1, 'day')) \
            .filterBounds(roi) \
            .filter(ee.Filter.eq('CLOUDY_PIXEL_PERCENTAGE', 0))

        if sen1.size().getInfo() == 0:
            print("No Sentinel-2 images available for this date and location.")
            return None

        sen1_image = sen1.select(['B4', 'B8']).mosaic()
    else:
        sen1_image = sen1.select(['VV', 'VH']).mosaic()

    despeckled = sen1_image.focal_mean(100, 'square', 'meters')
    vv_dark = despeckled.select('VV').lt(-22)
    vh_dark = despeckled.select('VH').lt(-18)
    oil_spill_detection = vv_dark.And(vh_dark)

    mask = oil_spill_detection.updateMask(oil_spill_detection)
    area = mask.multiply(ee.Image.pixelArea().divide(1e6))
    oil_spill_area = ee.Number(
        area.reduceRegion(
            reducer=ee.Reducer.sum(),
            geometry=roi,
            scale=100
        ).values().get(0)
    ).getInfo()

    if oil_spill_area > 0:
        print(f"Detected Oil Spill Area (sq. km): {oil_spill_area}")

        despeckled_np = geemap.ee_to_numpy(despeckled, bands=['VV', 'VH'], region=roi, scale=100)

        # Ensure image preprocessing for models
        #processed_image = preprocess_image_for_model(despeckled_np)

        # Confirm using all three models
        if confirm_oil_spill(hybrid_model, unet_model, deeplab_model, despeckled_np):
            detected_spills.append(oil_spill_area)

            # oil_spill_vis_params = {
            #     'min': 0,
            #     'max': 1,
            #     'palette': ['blue', 'cyan', 'yellow', 'red']
            # }

            # Visualization
            Map = geemap.Map()
            Map.centerObject(roi)
            Map.addLayer(sen1_image, {'bands': ['VV', 'VH'], 'min': -30, 'max': 0}, f'Sentinel-1 Image {anomaly_date.getInfo()}')
            Map.addLayer(despeckled.clip(roi), {}, 'Despeckled Image', False)
            Map.addLayer(oil_spill_detection.clip(roi), {}, 'Oil Spill Detection', False)
            oil_spill_vector = mask.reduceToVectors(
                geometry=roi,
                scale=100
            )
            Map.addLayer(oil_spill_vector, {}, 'Oil Spill Vector', False)

    if detected_spills:
        print(f"Oil spills detected over the days: {detected_spills}")
        Map.addLayerControl()
        return Map
    else:
        print("No significant oil spills detected across the checked dates.")
        return None
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Iterate over each anomaly in the DataFrame and process
for index, row in anomalies_df.iterrows():
    result_map = process_anomaly(row)
    if result_map:
        display(result_map)  # This displays the map in interactive environments
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing anomaly at 36.91337, -76.18496 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.91336, -76.18495 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.81622, -97.41844 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.81629, -97.41849 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.81629, -97.41839 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.7152, -76.70929 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71523, -76.70935 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71523, -76.70935 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71519, -76.70931 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71514, -76.70924 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71497, -76.70988 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71514, -76.70997 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71525, -76.70997 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71494, -76.70989 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71514, -76.70939 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.7094 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71515, -76.70936 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71509, -76.70947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71506, -76.70939 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71497, -76.70945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71502, -76.70942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71509, -76.70934 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71511, -76.70927 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71501, -76.70938 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71495, -76.7096 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71498, -76.70967 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71491, -76.70981 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.70919 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.70913 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71512, -76.70913 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71515, -76.70936 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71517, -76.70941 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71506, -76.70934 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71504, -76.70926 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71515, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.7152, -76.70933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71518, -76.70931 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71514, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71512, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.70924 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71515, -76.7093 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71512, -76.70925 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71509, -76.70922 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71521, -76.70941 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71505, -76.70922 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.70935 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71511, -76.70935 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.7093 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71481, -76.70993 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71517, -76.70964 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71509, -76.70927 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71519, -76.70931 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71513, -76.70931 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71519, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71519, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.7151, -76.7093 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71509, -76.70937 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71507, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71504, -76.70933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71507, -76.70933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71506, -76.70943 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71505, -76.70956 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71502, -76.70946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71501, -76.70952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71499, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71505, -76.70929 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71505, -76.70933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71504, -76.70931 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71504, -76.70926 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71505, -76.70926 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71506, -76.70928 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71506, -76.70928 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71502, -76.70933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71501, -76.70933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.715, -76.70927 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 34.71498, -76.70932 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37023, -89.92425 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37025, -89.92422 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37027, -89.92422 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37027, -89.92427 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37023, -89.92422 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37033, -89.9243 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37025, -89.92418 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.3703, -89.9242 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37028, -89.92417 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.37027, -89.92418 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 35.57524, -74.68039 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 30.39233, -81.41259 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.6867877705342
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39229, -81.41255 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.7307522294535
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 309ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39227, -81.41257 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.71322264529677
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 278ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.3923, -81.41257 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.71322264529677
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 292ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.3923, -81.41259 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.6921871443087
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 277ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39227, -81.41258 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.70270489480274
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 306ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39226, -81.41258 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.6843800843861
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 296ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39225, -81.41258 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.6843800843861
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 348ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39228, -81.41257 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.71322264529677
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 326ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39229, -81.4126 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.68166939381467
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 321ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39225, -81.41258 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.6843800843861
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 309ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.39231, -81.41259 on 2024-01-01
# Detected Oil Spill Area (sq. km): 86.6921871443087
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 366ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 36.9512, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.3294 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32954 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32956 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32954 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9513, -76.32953 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95129, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95128, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32953 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9514, -76.32968 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95136, -76.32961 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95128, -76.32955 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95117, -76.32953 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9513, -76.32953 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95116, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32954 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95128, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95117, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95128, -76.32955 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95129, -76.32962 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95114, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.3294 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32953 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32941 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95124, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32954 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95117, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32952 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32943 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.3294 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32933 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32938 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32943 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95115, -76.32938 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95115, -76.32934 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9512, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32948 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95116, -76.32943 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95116, -76.32943 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32955 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32939 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95117, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95138, -76.32959 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32947 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.9513, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32945 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95115, -76.32939 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95126, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32951 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32946 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32954 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95125, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95123, -76.3295 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32949 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95121, -76.32935 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95128, -76.3294 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95122, -76.32942 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95119, -76.32953 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 36.95118, -76.32944 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# ...
# 1/1 [==============================] - 0s 297ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92215, -124.11785 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.57030329885706
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 313ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.9222, -124.11785 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.733646983215955
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 308ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92222, -124.11787 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.7380894516864
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 305ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92227, -124.11788 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.740310685921614
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 300ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92228, -124.11789 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.905179778672625
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 375ms/step
# 1/1 [==============================] - 0s 357ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92233, -124.11785 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.89696391623581
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 349ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92244, -124.11778 on 2024-01-01
# Detected Oil Spill Area (sq. km): 38.04532103009072
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 362ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92231, -124.11782 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.890246710849404
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 324ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92207, -124.1179 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.580660141507956
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 302ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.9221, -124.11788 on 2024-01-01
# Detected Oil Spill Area (sq. km): 37.576217673037526
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 294ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92327, -124.11699 on 2024-01-01
# Detected Oil Spill Area (sq. km): 39.012035994350065
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 328ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92336, -124.11645 on 2024-01-01
# Detected Oil Spill Area (sq. km): 38.98469822317068
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 309ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92339, -124.11603 on 2024-01-01
# Detected Oil Spill Area (sq. km): 38.84725341361187
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 301ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92239, -124.11175 on 2024-01-01
# Detected Oil Spill Area (sq. km): 36.3004420176428
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 301ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92239, -124.11173 on 2024-01-01
# Detected Oil Spill Area (sq. km): 36.29418008563069
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 320ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92241, -124.11173 on 2024-01-01
# Detected Oil Spill Area (sq. km): 36.29418008563069
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 331ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 46.92242, -124.11168 on 2024-01-01
# Detected Oil Spill Area (sq. km): 36.28031776610327
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 3
#       1 # Iterate over each anomaly in the DataFrame and process
#       2 for index, row in anomalies_df.iterrows():
# ----> 3     result_map = process_anomaly(row)
#       4     if result_map:
#       5         display(result_map)  # This displays the map in interactive environments
#
# Cell In[46], line 60, in process_anomaly(row)
#      57 if oil_spill_area > 0:
#      58     print(f"Detected Oil Spill Area (sq. km): {oil_spill_area}")
# ---> 60     despeckled_np = geemap.ee_to_numpy(despeckled, bands=['VV', 'VH'], region=roi, scale=100)
#      62     # Ensure image preprocessing for models
#      63     #processed_image = preprocess_image_for_model(despeckled_np)
#      64
#      65     # Confirm using all three models
#      66     if confirm_oil_spill(hybrid_model, unet_model, deeplab_model, despeckled_np):
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\geemap\common.py:3134, in ee_to_numpy(ee_object, region, scale, bands, **kwargs)
#    3131     kwargs["bandIds"] = bands
#    3133 try:
# -> 3134     struct_array = ee.data.computePixels(kwargs)
#    3135     array = np.dstack(([struct_array[band] for band in struct_array.dtype.names]))
#    3136     return array
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:954, in computePixels(params)
#     950 params['fileFormat'] = _cloud_api_utils.convert_to_image_file_format(
#     951     converter.expected_data_format()
#     952 )
#     953 _maybe_populate_workload_tag(params)
# --> 954 data = _execute_cloud_call(
#     955     _get_cloud_projects_raw()
#     956     .image()
#     957     .computePixels(project=_get_projects_path(), body=params)
#     958 )
#     959 if converter:
#     960   return converter.do_conversion(data)
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:408, in _execute_cloud_call(call, num_retries)
#     406 num_retries = _max_retries if num_retries is None else num_retries
#     407 try:
# --> 408   return call.execute(num_retries=num_retries)
#     409 except googleapiclient.errors.HttpError as e:
#     410   raise _translate_cloud_exception(e)
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\_cloud_api_utils.py:70, in _Http.request(***failed resolving arguments***)
#      63 del redirections  # Ignored
#      65 try:
#      66   # googleapiclient is expecting an httplib2 object, and doesn't include
#      67   # requests error in the list of transient errors. Therefore, transient
#      68   # requests errors should be converted to kinds that googleapiclient
#      69   # consider transient.
# ---> 70   response = self._session.request(
#      71       method, uri, data=body, headers=headers, timeout=self._timeout
#      72   )
#      73 except requests.exceptions.ConnectionError as connection_error:
#      74   raise ConnectionError(connection_error) from connection_error
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066         data = self.read(amt=amt, decode_content=decode_content)
#    1068         if data:
#    1069             yield data
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Uday Kiran Ambati\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
